# %% [markdown]
# ### Визуальный анализ данных

# %% [markdown]
# Цель: посмотреть как выглядят данные для обучения, насколько сбалансированны классы

# %%
import os    
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
# блок импортов
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

import torch
# import torchvision module to handle image manipulation
import torchvision
import torchvision.transforms as transforms
import torchvision.datasets

# %%
MNIST_train = torchvision.datasets.MNIST('./',
                                         download=True,
                                         train=True,
                                         transform = transforms.Compose([
                                                      transforms.ToTensor()                                 
    ]))
MNIST_test = torchvision.datasets.MNIST('./',
                                        download=True
                                        , train=False,
                                        transform = transforms.Compose([
                                                    transforms.ToTensor()                                 
    ]))

# %%
border = 10
for img in MNIST_train.data:
    border = border - 1
    plt.imshow(255 - img, cmap='gray')
    plt.show()
    if border < 0:
        break

# %%
MNIST_train.targets
# Out:
# tensor([5, 0, 4,  ..., 5, 6, 8])

# %%
sns.countplot(MNIST_train.targets.numpy())
# Out:
# C:\Users\Calypso\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:ylabel='count'>

# %%
sns.countplot(MNIST_test.targets.numpy())
# Out:
# C:\Users\Calypso\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:ylabel='count'>
